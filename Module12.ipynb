# %%
import pandas as pd
df= pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 866

# %%
df1=df.dropna(axis=0)

# %%
import matplotlib.pyplot as plt
plt.boxplot(df1['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1802e49f880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1802e49fe20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1802e49f5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1802e4bf400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1802e4bf6d0>],
#  'means': []}

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2=pd.read_csv('stock_price.csv')
df2
# Out:
#          DATE    PRICE
# 0    1/1/1985  72.5052
# 1    2/1/1985  70.6720
# 2    3/1/1985  62.4502
# 3    4/1/1985  57.4714
# 4    5/1/1985  55.3151
# 5    6/1/1985      NaN
# 6    7/1/1985      NaN
# 7    8/1/1985      NaN
# 8    9/1/1985  60.5846
# 9   10/1/1985  60.5846
# 10  11/1/1985  60.6000
# 11  12/1/1985  61.6500
# 12   1/1/1986  62.5000
# 13   2/1/1986  62.5000
# 14   3/1/1986  62.2221

# %%
df3=df2['PRICE'].fillna(method='ffill')
df3
# Out:
# 0     72.5052
# 1     70.6720
# 2     62.4502
# 3     57.4714
# 4     55.3151
# 5     55.3151
# 6     55.3151
# 7     55.3151
# 8     60.5846
# 9     60.5846
# 10    60.6000
# 11    61.6500
# 12    62.5000
# 13    62.5000
# 14    62.2221
# Name: PRICE, dtype: float64

# %%
df4=df2['PRICE'].fillna(method='bfill', inplace=True)
df4

# %%
df.interpolate(method='quaddratic')
